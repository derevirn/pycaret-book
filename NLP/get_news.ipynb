# %%
import time, csv, os, json, requests
import pandas as pd
from newsapi import NewsApiClient

newsapi = NewsApiClient(api_key='85e6eaa3a79c4c458c69d1305f379eea')

# %%
domains = "reuters.com, scientificamerican.com,\
            espn.com, theverge.com"

all_articles = newsapi.get_everything(domains=domains,
                                      from_param='2021-10-21',
                                      to='2021-10-22',
                                      language='en',
                                      sort_by='relevancy',
                                      page=1)

df = pd.DataFrame(all_articles['articles'])

df
# Out:
#                                       source             author  \
# 0   {'id': 'the-verge', 'name': 'The Verge'}  Andrew J. Hawkins
# 1   {'id': 'the-verge', 'name': 'The Verge'}         Tom Warren
# 2   {'id': 'the-verge', 'name': 'The Verge'}        Loren Grush
# 3   {'id': 'the-verge', 'name': 'The Verge'}          Emma Roth
# 4   {'id': 'the-verge', 'name': 'The Verge'}   Cameron Faulkner
# 5   {'id': 'the-verge', 'name': 'The Verge'}  Andrew J. Hawkins
# 6   {'id': 'the-verge', 'name': 'The Verge'}          Emma Roth
# 7       {'id': 'reuters', 'name': 'Reuters'}               None
# 8       {'id': 'reuters', 'name': 'Reuters'}               None
# 9       {'id': 'reuters', 'name': 'Reuters'}               None
# 10      {'id': 'reuters', 'name': 'Reuters'}               None
# 11      {'id': 'reuters', 'name': 'Reuters'}               None
# 12      {'id': 'reuters', 'name': 'Reuters'}  Reuters Editorial
# 13      {'id': 'reuters', 'name': 'Reuters'}               None
# ...

# %%
for i in range(10, 12):
    all_articles = newsapi.get_everything(domains=domains,
                                      from_param='2021-10-21',
                                      to='2021-10-22',
                                      language='en',
                                      sort_by='relevancy',
                                      page=i)
    
    df = df.append(all_articles['articles'], ignore_index = True)
    
    time.sleep(1)

# %%
df
# Out:
#                                        source             author  \
# 0    {'id': 'the-verge', 'name': 'The Verge'}  Andrew J. Hawkins
# 1    {'id': 'the-verge', 'name': 'The Verge'}         Tom Warren
# 2    {'id': 'the-verge', 'name': 'The Verge'}        Loren Grush
# 3    {'id': 'the-verge', 'name': 'The Verge'}          Emma Roth
# 4    {'id': 'the-verge', 'name': 'The Verge'}   Cameron Faulkner
# ..                                        ...                ...
# 115      {'id': 'reuters', 'name': 'Reuters'}               None
# 116      {'id': 'reuters', 'name': 'Reuters'}               None
# 117      {'id': 'reuters', 'name': 'Reuters'}               None
# 118      {'id': 'reuters', 'name': 'Reuters'}               None
# 119      {'id': 'reuters', 'name': 'Reuters'}               None
#
#                                                  title  \
# 0    ‘Driverless’ Tesla crash in Texas wasn’t actua...
# 1    Intel’s unreleased Core i9-12900K processor go...
# ...
